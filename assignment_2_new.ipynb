# %% [markdown]
# <a href="https://colab.research.google.com/github/ak0982/AI-assignment/blob/master/assignment_2_new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

from scipy import stats

# %%
from google.colab import files 


uploaded = files.upload()
# Out:
#      <input type="file" id="files-1713bfe8-583b-436d-a302-b4f8d3c65e41" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1713bfe8-583b-436d-a302-b4f8d3c65e41">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving wine.csv to wine.csv

# %%
data=pd.read_csv('wine.csv')
#data.mean(axis=1,skipna=True)
data
# Out:
#      Wine  Alcohol  Malic.acid   Ash  ...  Color.int   Hue    OD  Proline
# 0       1    14.23        1.71  2.43  ...       5.64  1.04  3.92     1065
# 1       1    13.20        1.78  2.14  ...       4.38  1.05  3.40     1050
# 2       1    13.16        2.36  2.67  ...       5.68  1.03  3.17     1185
# 3       1    14.37        1.95  2.50  ...       7.80  0.86  3.45     1480
# 4       1    13.24        2.59  2.87  ...       4.32  1.04  2.93      735
# ..    ...      ...         ...   ...  ...        ...   ...   ...      ...
# 173     3    13.71        5.65  2.45  ...       7.70  0.64  1.74      740
# 174     3    13.40        3.91  2.48  ...       7.30  0.70  1.56      750
# 175     3    13.27        4.28  2.26  ...      10.20  0.59  1.56      835
# 176     3    13.17        2.59  2.37  ...       9.30  0.60  1.62      840
# 177     3    14.13        4.10  2.74  ...       9.20  0.61  1.60      560
#
# [178 rows x 14 columns]

# %%
scores=pd.read_csv('wine.csv',header=0)
scores
# Out:
#      Wine  Alcohol  Malic.acid   Ash  ...  Color.int   Hue    OD  Proline
# 0       1    14.23        1.71  2.43  ...       5.64  1.04  3.92     1065
# 1       1    13.20        1.78  2.14  ...       4.38  1.05  3.40     1050
# 2       1    13.16        2.36  2.67  ...       5.68  1.03  3.17     1185
# 3       1    14.37        1.95  2.50  ...       7.80  0.86  3.45     1480
# 4       1    13.24        2.59  2.87  ...       4.32  1.04  2.93      735
# ..    ...      ...         ...   ...  ...        ...   ...   ...      ...
# 173     3    13.71        5.65  2.45  ...       7.70  0.64  1.74      740
# 174     3    13.40        3.91  2.48  ...       7.30  0.70  1.56      750
# 175     3    13.27        4.28  2.26  ...      10.20  0.59  1.56      835
# 176     3    13.17        2.59  2.37  ...       9.30  0.60  1.62      840
# 177     3    14.13        4.10  2.74  ...       9.20  0.61  1.60      560
#
# [178 rows x 14 columns]

# %%
def mean(score):
  row_mean=score.mean(axis=1,skipna=True)
  col_mean=score.mean(axis=0,skipna=True)
  overall_mean=col_mean.mean()
  print('\nRow wise mean')
  print(row_mean)
  print('\ncolumn wise mean')
  print(col_mean)
  print('\noverall  mean')
  print(overall_mean)

def median(score):
  row_median=score.median(axis=1,skipna=True)
  col_median=score.median(axis=0,skipna=True)
  overall_median=col_median.median()
  print('\nRow wise def median-->')
  print(  row_median)
  print('\ncolumn wise median-->')
  print(col_median)
  print('\noverall  median-->')
  print(overall_median)

def mode(score):
  row_mode=score.mode(axis=1)
  col_mode=score.mode(axis=0)
  overall_mode=col_mode.mode()
  print('\nRow wise mode')
  print(row_mode)
  print('\ncolumn wise mode')
  print(col_mode)
  print('\noverall  mode')
  print(overall_mode)

def sd(score):
 
  row_sd=score.std(axis=1)
  col_sd=score.std(axis=0)
  overall_sd=col_sd.std()
  print('\nRow wise standard deviation-->')
  print(row_sd)
  print('\ncolumn wise standard deviation-->')
  print(col_sd)
  print('\noverall  standard deviation-->')
  print(overall_sd)




mean(scores)
median(scores)
mode(scores)
sd(scores)
# Out:
# Row wise mean
# 0       89.000000
# 1       85.364286
# 2       95.915714
# 3      117.963571
# 4       64.977857
#           ...
# 173     63.875714
# 174     65.124286
# 175     72.444286
# 176     72.640714
# 177     51.471429
# Length: 178, dtype: float64
#
# column wise mean
# Wine                      1.938202
# Alcohol                  13.000618
# Malic.acid                2.336348
# Ash                       2.366517
# Acl                      19.494944
# Mg                       99.741573
# Phenols                   2.295112
# Flavanoids                2.029270
# Nonflavanoid.phenols      0.361854
# Proanth                   1.590899
# Color.int                 5.058090
# Hue                       0.957449
# OD                        2.611685
# Proline                 746.893258
# dtype: float64
#
# overall  mean
# 64.33398715850723
#
# Row wise def median-->
# 0      2.930
# 1      2.705
# 2      2.990
# 3      3.470
# 4      2.835
#        ...
# 173    2.725
# ...

# %%
# part2 pearson correlation

features = pd.read_csv("wine.csv") 


col1 = features['Alcohol'] 
col2 = features['Proline'] 


corr=col1.corr(col2)
print('Pearsons correlation is  %.10f' % corr)
# Out:
# Pearsons correlation is  0.6437200372

# %%
arr2[]
# Out:
#      Wine  Alcohol  Malic.acid   Ash  ...  Color.int   Hue    OD  Proline
# 0       1    14.23        1.71  2.43  ...       5.64  1.04  3.92     1065
# 1       1    13.20        1.78  2.14  ...       4.38  1.05  3.40     1050
# 2       1    13.16        2.36  2.67  ...       5.68  1.03  3.17     1185
# 3       1    14.37        1.95  2.50  ...       7.80  0.86  3.45     1480
# 4       1    13.24        2.59  2.87  ...       4.32  1.04  2.93      735
# ..    ...      ...         ...   ...  ...        ...   ...   ...      ...
# 173     3    13.71        5.65  2.45  ...       7.70  0.64  1.74      740
# 174     3    13.40        3.91  2.48  ...       7.30  0.70  1.56      750
# 175     3    13.27        4.28  2.26  ...      10.20  0.59  1.56      835
# 176     3    13.17        2.59  2.37  ...       9.30  0.60  1.62      840
# 177     3    14.13        4.10  2.74  ...       9.20  0.61  1.60      560
#
# [178 rows x 14 columns]

# %%
#part2 covariance matrix

features = pd.read_csv("wine.csv") 


col1 = features['Alcohol'] 
col2 = features['Proline'] 
col3=features['Phenols'] 
col4=features['Flavanoids'] 
col5=features['Proanth'] 

df = pd.DataFrame([col1,col2,col3,col4,col5])
df.cov()
# Out:
#                0              1    ...            176            177
# 0    224492.721930  221445.308790  ...  177107.305085  117712.007740
# 1    221445.308790  218439.399020  ...  174702.843805  116113.609120
# 2    249935.187335  246542.521355  ...  197178.096270  131049.396030
# 3    312342.738765  308103.233720  ...  246411.611630  163769.906595
# 4    154667.413150  152567.716025  ...  122022.062900   81102.980175
# ..             ...            ...  ...            ...            ...
# 173  155915.427685  153798.569930  ...  123007.816895   81759.753855
# 174  158017.215635  155871.841680  ...  124665.662870   82861.045655
# 175  176051.420650  173661.287925  ...  138892.746200   92316.015325
# 176  177107.305085  174702.843805  ...  139725.669270   92869.420680
# 177  117712.007740  116113.609120  ...   92869.420680   61730.598670
#
# [178 rows x 178 columns]

# %%
#part2 covariance matrix

features = pd.read_csv("wine.csv") 
data=pd.read_csv('wine.csv')
df = pd.DataFrame(data.iloc[:,[1,2,3,4,5]].head())
df.cov()
# Out:
#              Alcohol  Malic.acid       Ash      Acl        Mg
# Alcohol     0.366250   -0.129900 -0.028125  -0.1970    4.4350
# Malic.acid -0.129900    0.145570  0.092605   1.1921   -0.5255
# Ash        -0.028125    0.092605  0.074470   0.9944    0.9105
# Acl        -0.197000    1.192100  0.994400  13.3880   13.6100
# Mg          4.435000   -0.525500  0.910500  13.6100  131.7000
