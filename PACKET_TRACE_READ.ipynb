# %% [markdown]
# <a href="https://colab.research.google.com/github/ak0982/AI-assignment/blob/master/PACKET_TRACE_READ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7633a5c4-225b-4cdc-8def-54f38b33fde9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7633a5c4-225b-4cdc-8def-54f38b33fde9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
data = pd.read_csv('Packet Trace (2).csv')
data
# Out:
#        PACKET_ID  SEGMENT_ID PACKET_TYPE  ... GATEWAY_IP NEXT_HOP_IP Unnamed: 26
# 0              1           0         CBR  ...   11.1.1.9    11.1.1.1         NaN
# 1              1           0         CBR  ...   11.1.1.2    11.1.1.5         NaN
# 2              1           0         CBR  ...   11.1.1.4    11.1.1.9         NaN
# 3              1           0         CBR  ...   11.1.1.9    11.1.1.1         NaN
# 4              1           0         CBR  ...   11.1.1.2    11.1.1.5         NaN
# ...          ...         ...         ...  ...        ...         ...         ...
# 75654       8462           0         CBR  ...   11.1.1.2    11.1.1.5         NaN
# 75655       4225           0         CBR  ...   11.1.1.4    11.1.1.8         NaN
# 75656       8412           0         CBR  ...   11.1.1.9    11.1.1.1         NaN
# 75657       8412           0         CBR  ...   11.1.1.9    11.1.1.1         NaN
# 75658       8462           0         CBR  ...   11.1.1.2    11.1.1.5         NaN
#
# ...

# %%
data.rename(columns = {'CONTROL_PACKET_TYPE/APP_NAME':'app'}, inplace = True)
print('APPLICATION          no. of new frames         no. of retransmitted frames'  )
def fun(str1):

  val1=data[data.app ==str1].shape[0]

  #print('TOTAL NO OF FRAME IN '+str1+' IS   {}'.format(val1))
  data1=data[data.app ==str1].tail(1)
  print()
  #print('NO of NEW FRAME IN '+str1 + '      {}'.format(data1['PACKET_ID'].values))
  print()
  #print(' no. of retransmitted frames is    {}'.format(abs(data1['PACKET_ID'].values-val1)))
  
  print(str1+'             {}                    {}-{}={}'.format(data1['PACKET_ID'].values,val1,data1['PACKET_ID'].values,abs(data1['PACKET_ID'].values-val1)))
  #print()
  
fun('App7_CBR')
fun('App8_CBR')
fun('App9_CBR')
fun('App10_CBR')
fun('App11_CBR')

#data['CONTROL_PACKET_TYPE/APP_NAME' =='App9_CBR']
# Out:
# APPLICATION          no. of new frames         no. of retransmitted frames
#
#
# App7_CBR             [8412]                    25064-[8412]=[16652]
#
#
# App8_CBR             [4225]                    11552-[4225]=[7327]
#
#
# App9_CBR             [4225]                    12590-[4225]=[8365]
#
#
# App10_CBR             [423]                    1264-[423]=[841]
#
#
# App11_CBR             [8462]                    25189-[8462]=[16727]
